# %% [markdown]
# <a href="https://colab.research.google.com/github/crahulnaidu/recursive-self-improving-ai/blob/main/month_1/ai_month_1_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
X=2*np.random.rand(100,1)
y=4+3*X+np.random.randn(100,1)

X_b=np.c_[np.ones((100,1)),X]
theta=np.random.randn(2,1)

lr=0.01
epochs=1000
loss=[]
id=[]

for epoch in range(epochs):
  gradients=2/100*(X_b.T.dot(X_b.dot(theta)-y))
  loss.append(np.mean(np.square(X_b.dot(theta)-y)))
  id.append(epoch)
  theta=theta-lr*gradients


print("learned parameters",theta)

plt.scatter(X,y)
plt.plot(X,X_b.dot(theta),color='red')
plt.title("Linear Regression fit")
plt.show()
# Out:
# learned parameters [[4.20607718]
#  [2.98273036]]

# %%
plt.scatter(loss,id)
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("loss vs epoch")
# Out:
# Text(0.5, 1.0, 'loss vs epoch')
