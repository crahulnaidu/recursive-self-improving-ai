# %% [markdown]
# <a href="https://colab.research.google.com/github/crahulnaidu/recursive-self-improving-ai/blob/main/month_1/ai_month_1_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Normal equation for linear Regression
#theta=(X.T*X)^-1*(X.T)*Y

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.random.rand(100,1)
y=4*X+3+np.random.randn(100,1)

X_b=np.c_[np.ones((100,1)),X]

theta_best=np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)


print(theta_best)
# Out:
# [[3.12393412]
#  [3.91570641]]

# %%
lr=0.1

epochs=10000
theta=np.random.randn(2,1)

for epoch in range(epochs):
  gradient=(2/(100))*X_b.T.dot(X_b.dot(theta)-y)
  theta=theta-lr*gradient

print(theta)
# Out:
# [[3.12393412]
#  [3.91570641]]

# %%
#time comparison

import time

start=time.time()

theta_best=np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

print("time taken for normal equation",time.time()-start)


start=time.time()
lr=0.1
theta=np.random.randn(2,1)
for epoch in range(1000):
  gradients=(2/100)*(X_b.T).dot(X_b.dot(theta)-y)
  theta=theta-gradients*lr

print("time taken for gradient descent",time.time()-start)
# Out:
# time taken for normal equation 0.0018320083618164062
# time taken for gradient descent 0.013773441314697266

# %%
a=np.random.rand(1000,1000)
b=np.random.rand(1000,1000)

start=time.time()

c=a@b

print(c)
print("time for computation",time.time()-start)
# Out:
# [[259.27344932 255.05791754 271.2204015  ... 261.35978064 257.09362364
#   255.02405128]
#  [246.85179025 248.32154883 259.49607078 ... 244.6871766  246.13152258
#   247.14234138]
#  [259.97764723 253.04115358 264.89680879 ... 254.30729044 257.37908009
#   251.93354469]
#  ...
#  [250.94374756 250.3627411  257.70731236 ... 247.50522096 248.71527238
#   249.38477308]
#  [239.94831229 241.7654337  249.94038803 ... 242.88571277 244.66822422
#   243.50724952]
#  [247.40044518 242.41609031 251.58820414 ... 238.50329392 238.73810318
#   238.56124368]]
# time for computation 0.11724996566772461
